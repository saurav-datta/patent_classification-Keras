# %% [markdown]
# # Multi-label Patent Classification

# %% [markdown]
# ### Questions for the team
# - Do we have year, to split train / test by year?
# - what did we do for patents with multiple documents ?
# - word-embeddings (train our own or use pre-trained ones)

# %%
# import packages 

import tensorflow as tf
import pandas as pd  
import numpy as np 
import gzip
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Input, Embedding, Reshape, Flatten, Conv1D, Conv2D, MaxPool2D, GlobalMaxPool1D, SpatialDropout1D
from keras.preprocessing import text, sequence
from keras import utils
from keras import optimizers, models

from sklearn import model_selection, preprocessing

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# load data 

# features 
current_dir = %pwd
abstract = pd.read_table(current_dir+'/out_zipped/docNumberToAbsText.txt.gz',compression='gzip', header=None)
abstract = abstract[0].str.split('|', expand=True).rename(columns={0:'doc_num',1:'abstract'})

claim = pd.read_table(current_dir+'/out_zipped/docNumberToClaimText.txt.gz',compression='gzip',  header=None)
claim = claim[0].str.split('|', expand=True).rename(columns={0:'doc_num',1:'claim'})

desc = pd.read_table(current_dir+'/out_zipped/docNumberToDescText.txt.gz',compression='gzip', header=None)
desc = desc[0].str.split('|', expand=True).rename(columns={0:'doc_num',1:'desc'})

title = pd.read_table(current_dir+'/out_zipped/docNumberToInvTitle.txt.gz',compression='gzip', header=None)
title = title[0].str.split('|', expand=True).rename(columns={0:'doc_num',1:'title'})

file_name = pd.read_table(current_dir+'/out_zipped/fileNameToDocNumber.txt.gz',compression='gzip', header=None)
file_name = file_name[0].str.split('|', expand=True).rename(columns={0:'file_name',1:'doc_num'})


# labels 
labels = pd.read_table(current_dir+'/out_zipped/docNumberToLabelSubClass.txt.gz',compression='gzip', header=None)
labels = labels[0].str.split('|', expand=True).rename(columns={0:'doc_num'})
clas = pd.read_table(current_dir+'/out_zipped/docNumberToClassText.txt.gz',compression='gzip', header=None)
clas = clas[0].str.split('|', expand=True).rename(columns={0:'doc_num'})

# %%
# joining the datasets using outer join, NOT removing the patents that are missing sections
# DISCUSSION: should we change it to inner join (i.e. removing the patents that are missing sections)
X = pd.concat([title.set_index('doc_num'), 
           abstract.set_index('doc_num'), 
           claim.set_index('doc_num'), 
           desc.set_index('doc_num')], axis=1).sort_index() #  join='inner'

Y = labels.set_index('doc_num').sort_index() #.set_index(X.index) # fixing the index mismatch
Y.columns=["label{}".format(i) for i in range(1,15)] # renaming columns 

print(X.shape)
print(Y.shape)
# Out:
# (25000, 4)
# (25000, 14)

# %%
# Out:
#         doc_num                                       1  \
# 0      99203729  B28B0001000000~20060101C I20051008RMEP
# 1      99203719  A01J0005007000~20060101C I20051008RMEP
# 2      99122031  A01K0001010000~20060101A I20051008RMEP
# 3      98921499  A01K0011000000~20060101A I20051008RMEP
# 4      99122657  A01K0063000000~20060101A I20051008RMEP
# 5      99650107  A01B0079000000~20060101A I20051008RMEP
# 6      99308702  A01N0001020000~20060101A I20051008RMEP
# 7      99203496  A01N0035000000~20060101C I20051008RMEP
# 8      98923143  A01N0043480000~20060101C I20051008RMEP
# 9      99203439  A22C0021000000~20060101A I20051008RMEP
# 10     99922567  A23B0007100000~20060101A I20051008RMEP
# 11     99121962  A23C0011000000~20060101CFI20051220RMJP
# 12     99118767  A23G0003020000~20060101A I20051008RMEP
# 13     99118766  A23G0003020000~20060101A I20051008RMEP
# 14     99308995  A23L0001100000~20060101AFI20060101BMKR
# 15     99203776  A23L0003320000~20060101A I20051008RMEP
# 16     98120120  A63B0071080000~20060101C I20051008RMEP
# 17     99309050  A42B0003180000~20060101C I20051008RMEP
# 18     99650061  A44C0009000000~20060101C I20051008RMEP
# 19     99850165  A01K0097060000~20060101A I20051008RMEP
# 20     99420221  A46B0003000000~20060101C I20051008RMEP
# 21     99115488  A47B0017000000~20060101C I20051008RMEP
# 22     99922635  A47C0003000000~20060101C I20051008RMEP
# 23     98830683  A47C0021000000~20060101C I20051008RMEP
# 24     99500204  A47D0013000000~20060101C I20051008RMEP
# 25     99122045  A47F0003040000~20060101A I20051008RMEP
# 26     99500179  A47J0027080000~20060101A I20051008RMEP
# 27     99308668  A47J0031440000~20060101C I20051008RMEP
# 28     99500209  A47K0005000000~20060101C I20051008RMEP
# 29     98870244  A47K0010000000~20060101CFI20051220RMJP
# ...         ...                                     ...
# 24970  00402119  A61M0001100000~20060101A I20051008RMEP
# 24971  99912100  A61M0001100000~20060101A I20051008RMEP
# 24972  00306238  A61B0005000000~20060101A I20070224RMEP
# 24973  00201947  A61D0007000000~20060101A I20051008RMEP
# 24974  00402090  A61N0001050000~20060101A I20051008RMEP
# 24975  00304817  A61N0001365000~20060101A I20051008RMEP
# 24976  00111026  A61N0001400000~20060101A I20051008RMEP
# 24977  00201946  A61M0036000000~20060101C I20060521RMUS
# 24978  99922188  A63B0059000000~20060101A I20051008RMEP
# 24979  00115011  A63F0001000000~20060101C I20051008RMEP
# 24980  00902085  A63F0005040000~20060101AFI20051220RMJP
# 24981  00115009  A63F0013100000~20060101A I20051008RMEP
# 24982  00115010  A63F0001000000~20060101A N20051008RMEP
# 24983  00305832  B01D0019020000~20060101C I20051008RMEP
# 24984  99202365  B01D0021000000~20060101A I20051008RMEP
# 24985  99309041  B01D0027000000~20060101C I20051008RMEP
# 24986  99309038  B01D0027000000~20060101C I20051008RMEP
# 24987  99309039  B01D0027000000~20060101C I20051008RMEP
# 24988  00305991  B01D0053040000~20060101A I20051008RMEP
# 24989  99310145  B01D0045000000~20060101C I20051008RMEP
# 24990  00902024  B01D0039200000~20060101AFI20051220RMJP
# 24991  00902025  B01D0039200000~20060101AFI20051220RMJP
# 24992  00114962  B01F0005060000~20060101CLI20051220RMJP
# 24993  00116907  B01J0019300000~20060101A I20051008RMEP
# 24994  00306096  B01D0053020000~20060101A I20051008RMEP
# 24995  00306105  B01D0053040000~20060101A I20051008RMEP
# 24996  00306061  B01L0003020000~20060101A I20051008RMEP
# 24997  00306280  B01L0003000000~20060101A I20051008RMEP
# 24998  00305966  B01J0019000000~20060101A I20051008RMEP
# 24999  99947861  B01J0002000000~20060101ALI20051220RMJP
#
#                                             2  \
# 0      B28B0001290000~20060101A I20051008RMEP
# 1      A01J0005010000~20060101A I20051008RMEP
# 2      A01K0001010000~20060101C I20051008RMEP
# 3      A01K0011000000~20060101C I20051008RMEP
# 4      A01K0063000000~20060101C I20051008RMEP
# 5      A01B0079000000~20060101C I20051008RMEP
# 6      A01N0001020000~20060101C I20051008RMEP
# 7      A01N0035020000~20060101A I20051008RMEP
# 8      A01N0043600000~20060101A I20051008RMEP
# 9      A22C0021000000~20060101C I20051008RMEP
# 10     A23B0007100000~20060101C I20051008RMEP
# 11     A23C0011100000~20060101AFI20051220RMJP
# 12     A23G0003020000~20060101C I20051008RMEP
# 13     A23G0003020000~20060101C I20051008RMEP
# 14     A23L0001100000~20060101CFI20060101BMKR
# 15     A23L0003320000~20060101C I20051008RMEP
# 16     A63B0071140000~20060101A I20051008RMEP
# 17     A42B0003220000~20060101A I20051008RMEP
# 18     A44C0009020000~20060101A I20051008RMEP
# 19     A01K0097060000~20060101C I20051008RMEP
# 20     A46B0003180000~20060101A I20051008RMEP
# 21     A47B0017030000~20060101A I20051008RMEP
# 22     A47C0003180000~20060101A I20051008RMEP
# 23     A47C0021040000~20060101A I20051008RMEP
# 24     A47D0013020000~20060101A I20051008RMEP
# 25     A47F0003040000~20060101C I20051008RMEP
# 26     A47J0027080000~20060101C I20051008RMEP
# 27     A47J0031460000~20060101A I20051008RMEP
# 28     A47K0005120000~20060101A I20051008RMEP
# 29     A47K0010200000~20060101AFI20051220RMJP
# ...                                       ...
# 24970  A61M0001100000~20060101C I20051008RMEP
# 24971  A61M0001100000~20060101C I20051008RMEP
# 24972  A61B0005000000~20060101C I20070224RMEP
# 24973  A61D0007000000~20060101C I20051008RMEP
# 24974  A61N0001050000~20060101C I20051008RMEP
# 24975  A61N0001365000~20060101C I20051008RMEP
# 24976  A61N0001400000~20060101C I20051008RMEP
# 24977  A61M0036120000~20060101A I20060521RMUS
# 24978  A63B0059000000~20060101C I20051008RMEP
# 24979  A63F0001180000~20060101A I20051008RMEP
# 24980  A63F0005040000~20060101CFI20051220RMJP
# 24981  A63F0013100000~20060101C I20051008RMEP
# 24982  A63F0001000000~20060101C N20051008RMEP
# 24983  B01D0019040000~20060101A I20051008RMEP
# 24984  B01D0021000000~20060101C I20051008RMEP
# 24985  B01D0027060000~20060101A I20051008RMEP
# 24986  B01D0027060000~20060101A I20051008RMEP
# 24987  B01D0027060000~20060101A I20051008RMEP
# 24988  B01D0053040000~20060101C I20051008RMEP
# 24989  B01D0045060000~20060101A I20051008RMEP
# 24990  B01D0039200000~20060101CFI20051220RMJP
# 24991  B01D0039200000~20060101CFI20051220RMJP
# 24992  B01F0005080000~20060101ALI20051220RMJP
# 24993  B01J0019300000~20060101C I20051008RMEP
# 24994  B01D0053020000~20060101C I20051008RMEP
# 24995  B01D0053040000~20060101C I20051008RMEP
# 24996  B01L0003020000~20060101C I20051008RMEP
# 24997  B01L0003000000~20060101C I20051008RMEP
# 24998  B01J0019000000~20060101C I20051008RMEP
# 24999  B01J0002000000~20060101CLI20051220RMJP
#
#                                             3  \
# 0      B28B0005000000~20060101C I20051008RMEP
# 1      A01J0011000000~20060101AFI20051220RMJP
# 2                                        None
# 3                                        None
# 4      A01K0063040000~20060101A I20051008RMEP
# 5      A01M0007000000~20060101A I20051008RMEP
# 6      A61K0009080000~20060101AFI20051220RMJP
# 7      C12N0015820000~20060101A I20051008RMEP
# 8                                        None
# 9                                        None
# 10     A23L0001226000~20060101C I20051008RMEP
# 11     A23F0005240000~20060101ALI20051220RMJP
# 12     A23G0003200000~20060101A I20051008RMEP
# 13     A23G0003200000~20060101A I20051008RMEP
# 14     A23L0001180000~20060101A I20051008RMEP
# 15     A61L0002020000~20060101A I20051008RMEP
# 16                                       None
# 17                                       None
# 18                                       None
# 19     A42B0001000000~20060101C I20051008RMEP
# 20     A46B0009000000~20060101C I20051008RMEP
# 21     A47B0021000000~20060101C I20051008RMEP
# 22                                       None
# 23     F24H0003040000~20060101A N20051008RMEP
# 24     B60N0002260000~20060101C I20051008RMEP
# 25     A47F0005100000~20060101A I20051008RMEP
# 26                                       None
# 27     A47J0031540000~20060101A I20051008RMEP
# 28                                       None
# 29     A47K0010240000~20060101C I20051008RMEP
# ...                                       ...
# 24970  F04D0013020000~20060101A I20051008RMEP
# 24971                                    None
# 24972  A61M0025000000~20060101A I20070224RMEP
# 24973  A61M0036000000~20060101C I20060521RMUS
# 24974                                    None
# 24975                                    None
# 24976                                    None
# 24977  A61N0005100000~20060101A I20051008RMEP
# 24978  A63B0067000000~20060101A I20051008RMEP
# 24979  A63F0013000000~20060101AFI20051220RMJP
# 24980  A63F0009000000~20060101A I20051008RMEP
# 24981                                    None
# 24982  A63F0003080000~20060101A N20051008RMEP
# 24983  C08G0077000000~20060101CLI20051220RMJP
# 24984  B01D0021280000~20060101A I20060521RMEP
# 24985  B01D0035300000~20060101A I20051008RMEP
# 24986                                    None
# 24987  B01D0035300000~20060101A I20051008RMEP
# 24988  B01D0053047000~20060101A I20051008RMEP
# 24989  B01D0053380000~20060101A I20051008RMEP
# 24990  B01D0069000000~20060101C I20051008RMEP
# 24991  B01D0069000000~20060101C I20051008RMEP
# 24992  B01J0002200000~20060101A I20051008RMEP
# 24993  B01J0019320000~20060101A I20051008RMEP
# 24994  B01J0020220000~20060101A I20051008RMEP
# 24995  B01J0020220000~20060101C I20051008RMEP
# 24996  B67D0005000000~20060101AFI20051220RMJP
# 24997  G01N0001000000~20060101A I20051008RMEP
# 24998  B01L0011000000~20060101A I20051008RMEP
# 24999  B02B0001000000~20060101C I20051008RMEP
#
#                                             4  \
# 0      B28B0005020000~20060101A I20051008RMEP
# 1      A01J0011000000~20060101CFI20051220RMJP
# 2                                        None
# 3                                        None
# 4      A01K0063040000~20060101C I20051008RMEP
# 5      A01M0007000000~20060101C I20051008RMEP
# 6      A61K0009080000~20060101CFI20051220RMJP
# 7      C12N0015820000~20060101C I20051008RMEP
# 8                                        None
# 9                                        None
# 10     A23L0001230000~20060101A I20051008RMEP
# 11     A23F0005240000~20060101C I20051008RMEP
# 12                                       None
# 13     A23G0007000000~20060101A I20051008RMEP
# 14     A23L0001180000~20060101C I20051008RMEP
# 15     A61L0002020000~20060101C I20051008RMEP
# 16                                       None
# 17                                       None
# 18                                       None
# 19     A42B0001040000~20060101C I20051008RMEP
# 20     A46B0009020000~20060101A I20051008RMEP
# 21     A47B0021030000~20060101A I20051008RMEP
# 22                                       None
# 23     F24H0003040000~20060101C N20051008RMEP
# 24     B60N0002280000~20060101A I20051008RMEP
# 25     A47F0005100000~20060101C I20051008RMEP
# 26                                       None
# 27                                       None
# 28                                       None
# 29     A47K0010320000~20060101A N20051008RMEP
# ...                                       ...
# 24970  F04D0013020000~20060101C I20051008RMEP
# 24971                                    None
# 24972  A61M0025000000~20060101C I20070224RMEP
# 24973  A61M0036040000~20060101A I20060521RMUS
# 24974                                    None
# 24975                                    None
# 24976                                    None
# 24977  A61N0005100000~20060101C I20051008RMEP
# 24978  A63B0067000000~20060101C I20051008RMEP
# 24979  A63F0013000000~20060101CFI20051220RMJP
# 24980  A63F0009000000~20060101C I20051008RMEP
# 24981                                    None
# 24982  A63F0003080000~20060101C N20051008RMEP
# 24983  C08G0077140000~20060101ALI20051220RMJP
# 24984  C02F0001463000~20060101A N20051008RMEP
# 24985  B01D0035300000~20060101C I20051008RMEP
# 24986                                    None
# 24987  B01D0035300000~20060101C I20051008RMEP
# 24988  B01D0053047000~20060101C I20051008RMEP
# 24989  B01D0053380000~20060101C I20051008RMEP
# 24990  B01D0069100000~20060101A I20051008RMEP
# 24991  B01D0069100000~20060101A I20051008RMEP
# 24992  B01J0002200000~20060101C I20051008RMEP
# 24993  B01J0019320000~20060101C I20051008RMEP
# 24994  B01J0020220000~20060101C I20051008RMEP
# 24995  B01J0020260000~20060101A I20051008RMEP
# 24996  B67D0005000000~20060101CFI20051220RMJP
# 24997  G01N0001000000~20060101C I20051008RMEP
# 24998  B01L0011000000~20060101C I20051008RMEP
# 24999  B02B0001020000~20060101A I20051008RMEP
#
#                                             5  \
# 0      B28B0007000000~20060101A I20051008RMEP
# 1      G01N0021250000~20060101CLI20051220RMJP
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6      C12N0005060000~20060101A I20051008RMEP
# 7                                        None
# 8                                        None
# 9                                        None
# 10     C12P0017020000~20060101C I20051008RMEP
# 11     A23F0005340000~20060101A I20051008RMEP
# 12                                       None
# 13     A23G0007000000~20060101C I20051008RMEP
# 14                                       None
# 15     C02F0001480000~20060101A I20051008RMEP
# 16                                       None
# 17                                       None
# 18                                       None
# 19     A42B0001060000~20060101A I20051008RMEP
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25     A47F0009000000~20060101A I20051008RMEP
# 26                                       None
# 27                                       None
# 28                                       None
# 29     A47K0010420000~20060101A I20051008RMEP
# ...                                       ...
# 24970  F04D0013060000~20060101A I20051008RMEP
# 24971                                    None
# 24972  A61M0025010000~20060101AFI20051220RMJP
# 24973  A61N0005100000~20060101A I20051008RMEP
# 24974                                    None
# 24975                                    None
# 24976                                    None
# 24977                                    None
# 24978  A63B0069000000~20060101AFI20051220RMJP
# 24979  A63F0013100000~20060101ALI20051220RMJP
# 24980  G07F0017320000~20060101A I20051008RMEP
# 24981                                    None
# 24982  A63F0009240000~20060101A I20051008RMEP
# 24983  C08G0077220000~20060101ALI20051220RMJP
# 24984  C02F0001463000~20060101C N20051008RMEP
# 24985                                    None
# 24986                                    None
# 24987                                    None
# 24988                                    None
# 24989  B01J0019240000~20060101A I20051008RMEP
# 24990  B01D0071000000~20060101C I20051008RMEP
# 24991  B01D0071000000~20060101C I20051008RMEP
# 24992  B01J0019000000~20060101AFI20051220RMJP
# 24993                                    None
# 24994  B01J0020260000~20060101A I20051008RMEP
# 24995  C08G0079000000~20060101A I20051008RMEP
# 24996  G01N0035100000~20060101A I20051008RMEP
# 24997                                    None
# 24998  C40B0060140000~20060101A N20070721RMEP
# 24999  B02C0002000000~20060101C I20051008RMEP
#
#                                             6  \
# 0      B28B0007000000~20060101C I20051008RMEP
# 1      G01N0021270000~20060101ALI20051220RMJP
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6      C12N0005060000~20060101C I20051008RMEP
# 7                                        None
# 8                                        None
# 9                                        None
# 10     C12P0017040000~20060101A I20051008RMEP
# 11     A23F0005400000~20060101A I20051008RMEP
# 12                                       None
# 13     A23G0009040000~20060101C I20051008RMEP
# 14                                       None
# 15     C02F0001480000~20060101C I20051008RMEP
# 16                                       None
# 17                                       None
# 18                                       None
# 19     A42B0001240000~20060101A I20051008RMEP
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25     A47F0009000000~20060101C I20051008RMEP
# 26                                       None
# 27                                       None
# 28                                       None
# 29     B65D0025380000~20060101CLI20051220RMJP
# ...                                       ...
# 24970  F04D0013060000~20060101C I20051008RMEP
# 24971                                    None
# 24972  A61M0025010000~20060101CFI20051220RMJP
# 24973  A61N0005100000~20060101C I20051008RMEP
# 24974                                    None
# 24975                                    None
# 24976                                    None
# 24977                                    None
# 24978  A63B0069000000~20060101CFI20051220RMJP
# 24979  A63F0013100000~20060101CLI20051220RMJP
# 24980  G07F0017320000~20060101C I20051008RMEP
# 24981                                    None
# 24982  A63F0009240000~20060101C I20051008RMEP
# 24983  C11D0003000000~20060101A I20051008RMEP
# 24984                                    None
# 24985                                    None
# 24986                                    None
# 24987                                    None
# 24988                                    None
# 24989  B01J0019240000~20060101C I20051008RMEP
# 24990  B01D0071020000~20060101A I20051008RMEP
# 24991  B01D0071020000~20060101A I20051008RMEP
# 24992  B01J0019000000~20060101CFI20051220RMJP
# 24993                                    None
# 24994  C01B0013020000~20060101A I20051008RMEP
# 24995  C08G0079000000~20060101C I20051008RMEP
# 24996  G01N0035100000~20060101C I20051008RMEP
# 24997                                    None
# 24998  C40B0060140000~20060101C N20070721RMEP
# 24999  B02C0002100000~20060101A I20051008RMEP
#
#                                             7  \
# 0      H02P0006080000~20060101A I20051008RMEP
# 1      G01N0033020000~20060101CLI20051220RMJP
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# 9                                        None
# 10                                       None
# 11                                       None
# 12                                       None
# 13     A23G0009260000~20060101A I20051008RMEP
# 14                                       None
# 15                                       None
# 16                                       None
# 17                                       None
# 18                                       None
# 19     A45F0005000000~20060101C I20051008RMEP
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25                                       None
# 26                                       None
# 27                                       None
# 28                                       None
# 29     B65D0025520000~20060101ALI20051220RMJP
# ...                                       ...
# 24970  F04D0015020000~20060101A I20051008RMEP
# 24971                                    None
# 24972  A61M0025090000~20060101A I20060521RMEP
# 24973                                    None
# 24974                                    None
# 24975                                    None
# 24976                                    None
# 24977                                    None
# 24978  A63B0071000000~20060101A I20051008RMEP
# 24979                                    None
# 24980  G07F0017380000~20060101A I20051008RMEP
# 24981                                    None
# 24982  A63F0013000000~20060101AFI20051220RMJP
# 24983  C11D0003000000~20060101C I20051008RMEP
# 24984                                    None
# 24985                                    None
# 24986                                    None
# 24987                                    None
# 24988                                    None
# 24989                                    None
# 24990  C04B0038000000~20060101ALI20051220RMJP
# 24991  C04B0038000000~20060101ALI20051220RMJP
# 24992  B02C0019000000~20060101ALI20051220RMJP
# 24993                                    None
# 24994  C01B0013020000~20060101C I20051008RMEP
# 24995                                    None
# 24996                                    None
# 24997                                    None
# 24998  G01N0035020000~20060101A N20051008RMEP
# 24999  B02C0004000000~20060101CFI20051220RMJP
#
#                                             8  \
# 0      H02P0006080000~20060101C I20051008RMEP
# 1      G01N0033040000~20060101ALI20051220RMJP
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# 9                                        None
# 10                                       None
# 11                                       None
# 12                                       None
# 13                                       None
# 14                                       None
# 15                                       None
# 16                                       None
# 17                                       None
# 18                                       None
# 19     A45F0005020000~20060101A I20051008RMEP
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25                                       None
# 26                                       None
# 27                                       None
# 28                                       None
# 29     B65D0043140000~20060101CLI20051220RMJP
# ...                                       ...
# 24970  F04D0015020000~20060101C I20051008RMEP
# 24971                                    None
# 24972  A61M0025090000~20060101C I20060521RMEP
# 24973                                    None
# 24974                                    None
# 24975                                    None
# 24976                                    None
# 24977                                    None
# 24978  A63B0071000000~20060101C I20051008RMEP
# 24979                                    None
# 24980                                    None
# 24981                                    None
# 24982  A63F0013000000~20060101CFI20051220RMJP
# 24983  C11D0003040000~20060101ALI20051220RMJP
# 24984                                    None
# 24985                                    None
# 24986                                    None
# 24987                                    None
# 24988                                    None
# 24989                                    None
# 24990  C04B0038000000~20060101CLI20051220RMJP
# 24991  C04B0038000000~20060101CLI20051220RMJP
# 24992  B02C0019000000~20060101CLI20051220RMJP
# 24993                                    None
# 24994  C07C0255000000~20060101C I20051008RMEP
# 24995                                    None
# 24996                                    None
# 24997                                    None
# 24998  G01N0035020000~20060101C N20051008RMEP
# 24999  B02C0004340000~20060101AFI20051220RMJP
#
#                                             9  ...    100   101   102   103  \
# 0                                        None  ...   None  None  None  None
# 1                                        None  ...   None  None  None  None
# 2                                        None  ...   None  None  None  None
# 3                                        None  ...   None  None  None  None
# 4                                        None  ...   None  None  None  None
# 5                                        None  ...   None  None  None  None
# 6                                        None  ...   None  None  None  None
# 7                                        None  ...   None  None  None  None
# 8                                        None  ...   None  None  None  None
# 9                                        None  ...   None  None  None  None
# 10                                       None  ...   None  None  None  None
# 11                                       None  ...   None  None  None  None
# 12                                       None  ...   None  None  None  None
# 13                                       None  ...   None  None  None  None
# 14                                       None  ...   None  None  None  None
# 15                                       None  ...   None  None  None  None
# 16                                       None  ...   None  None  None  None
# 17                                       None  ...   None  None  None  None
# 18                                       None  ...   None  None  None  None
# 19     A61F0009040000~20060101A N20051008RMEP  ...   None  None  None  None
# 20                                       None  ...   None  None  None  None
# 21                                       None  ...   None  None  None  None
# 22                                       None  ...   None  None  None  None
# 23                                       None  ...   None  None  None  None
# 24                                       None  ...   None  None  None  None
# 25                                       None  ...   None  None  None  None
# 26                                       None  ...   None  None  None  None
# 27                                       None  ...   None  None  None  None
# 28                                       None  ...   None  None  None  None
# 29     B65D0043160000~20060101A I20051008RMEP  ...   None  None  None  None
# ...                                       ...  ...    ...   ...   ...   ...
# 24970                                    None  ...   None  None  None  None
# 24971                                    None  ...   None  None  None  None
# 24972                                    None  ...   None  None  None  None
# 24973                                    None  ...   None  None  None  None
# 24974                                    None  ...   None  None  None  None
# 24975                                    None  ...   None  None  None  None
# 24976                                    None  ...   None  None  None  None
# 24977                                    None  ...   None  None  None  None
# 24978  A63B0071020000~20060101ALI20051220RMJP  ...   None  None  None  None
# 24979                                    None  ...   None  None  None  None
# 24980                                    None  ...   None  None  None  None
# 24981                                    None  ...   None  None  None  None
# 24982  A63F0013100000~20060101ALI20051220RMJP  ...   None  None  None  None
# 24983  C11D0003040000~20060101CLI20051220RMJP  ...   None  None  None  None
# 24984                                    None  ...   None  None  None  None
# 24985                                    None  ...   None  None  None  None
# 24986                                    None  ...   None  None  None  None
# 24987                                    None  ...   None  None  None  None
# 24988                                    None  ...   None  None  None  None
# 24989                                    None  ...   None  None  None  None
# 24990  C04B0041450000~20060101A I20051008RMEP  ...   None  None  None  None
# 24991  C04B0041450000~20060101A I20051008RMEP  ...   None  None  None  None
# 24992  B30B0011220000~20060101A I20051008RMEP  ...   None  None  None  None
# 24993                                    None  ...   None  None  None  None
# 24994  C07C0255240000~20060101A I20051008RMEP  ...   None  None  None  None
# 24995                                    None  ...   None  None  None  None
# 24996                                    None  ...   None  None  None  None
# 24997                                    None  ...   None  None  None  None
# 24998  G02B0025000000~20060101A I20051008RMEP  ...   None  None  None  None
# 24999  B02C0007000000~20060101C I20060722RMEP  ...   None  None  None  None
#
#         104   105   106   107   108   109
# 0      None  None  None  None  None  None
# 1      None  None  None  None  None  None
# 2      None  None  None  None  None  None
# 3      None  None  None  None  None  None
# 4      None  None  None  None  None  None
# 5      None  None  None  None  None  None
# 6      None  None  None  None  None  None
# 7      None  None  None  None  None  None
# 8      None  None  None  None  None  None
# 9      None  None  None  None  None  None
# 10     None  None  None  None  None  None
# 11     None  None  None  None  None  None
# 12     None  None  None  None  None  None
# 13     None  None  None  None  None  None
# 14     None  None  None  None  None  None
# 15     None  None  None  None  None  None
# 16     None  None  None  None  None  None
# 17     None  None  None  None  None  None
# 18     None  None  None  None  None  None
# 19     None  None  None  None  None  None
# 20     None  None  None  None  None  None
# 21     None  None  None  None  None  None
# 22     None  None  None  None  None  None
# 23     None  None  None  None  None  None
# 24     None  None  None  None  None  None
# 25     None  None  None  None  None  None
# 26     None  None  None  None  None  None
# 27     None  None  None  None  None  None
# 28     None  None  None  None  None  None
# 29     None  None  None  None  None  None
# ...     ...   ...   ...   ...   ...   ...
# 24970  None  None  None  None  None  None
# 24971  None  None  None  None  None  None
# 24972  None  None  None  None  None  None
# 24973  None  None  None  None  None  None
# 24974  None  None  None  None  None  None
# 24975  None  None  None  None  None  None
# 24976  None  None  None  None  None  None
# 24977  None  None  None  None  None  None
# 24978  None  None  None  None  None  None
# 24979  None  None  None  None  None  None
# 24980  None  None  None  None  None  None
# 24981  None  None  None  None  None  None
# 24982  None  None  None  None  None  None
# 24983  None  None  None  None  None  None
# 24984  None  None  None  None  None  None
# 24985  None  None  None  None  None  None
# 24986  None  None  None  None  None  None
# 24987  None  None  None  None  None  None
# 24988  None  None  None  None  None  None
# 24989  None  None  None  None  None  None
# 24990  None  None  None  None  None  None
# 24991  None  None  None  None  None  None
# 24992  None  None  None  None  None  None
# 24993  None  None  None  None  None  None
# 24994  None  None  None  None  None  None
# 24995  None  None  None  None  None  None
# 24996  None  None  None  None  None  None
# 24997  None  None  None  None  None  None
# 24998  None  None  None  None  None  None
# 24999  None  None  None  None  None  None
#
# [25000 rows x 110 columns]

# %%
1000 columns 
semi    alloys   other    some_other 

1          0       1         1
# Out:
#                                                      label1  \
# doc_num
# 00100004  SEMICONDUCTOR DEVICES; ELECTRIC SOLID STATE DE...
# 00100005   IMAGE DATA PROCESSING OR GENERATION, IN GENERAL
# 00100008                                        WIND MOTORS
# 00100009  SHAPING OR JOINING OF PLASTICS; SHAPING OF SUB...
# 00100010  APPARATUS OR DEVICES FOR MANIFOLDING, DUPLICAT...
# 00100018                  ELECTRIC DIGITAL DATA PROCESSING
# 00100023  SHAPING OR JOINING OF PLASTICS; SHAPING OF SUB...
# 00100027                                      TRANSMISSION
# 00100028               COUPLINGS FOR TRANSMITTING ROTATION
# 00100029  MATERIALS FOR APPLICATIONS NOT OTHERWISE PROVI...
# 00100030  MEASURING DISTANCES, LEVELS OR BEARINGS; SURVE...
# 00100031                                      TRANSMISSION
# 00100039  CHEMICAL OR PHYSICAL PROCESSES, e.g. CATALYSIS...
# 00100040           OPTICAL ELEMENTS, SYSTEMS, OR APPARATUS
# 00100042   IMAGE DATA PROCESSING OR GENERATION, IN GENERAL
# 00100043  COUNTING MECHANISMS; COUNTING OF OBJECTS NOT O...
# 00100049  MAGNETS; INDUCTANCES; TRANSFORMERS; SELECTION ...
# 00100050  REFRIGERATORS; COLD ROOMS; ICE-BOXES; COOLING ...
# 00100051  RECOGNITION OF DATA; PRESENTATION OF DATA; REC...
# 00100053                     MANUFACTURE OF DAIRY PRODUCTS
# 00100054                              STEREOPHONIC SYSTEMS
# 00100065  SPEECH ANALYSIS OR SYNTHESIS; SPEECH RECOGNITI...
# 00100066  DENTISTRY; APPARATUS OR METHODS FOR ORAL OR DE...
# 00100069  CONTROL OR REGULATING SYSTEMS IN GENERAL; FUNC...
# 00100071  CAPACITORS; CAPACITORS, RECTIFIERS, DETECTORS,...
# 00100072  ELECTROGRAPHY; ELECTROPHOTOGRAPHY; MAGNETOGRAPHY
# 00100073  ELECTROGRAPHY; ELECTROPHOTOGRAPHY; MAGNETOGRAPHY
# 00100074                                        SEPARATION
# 00100075  SPRAYING APPARATUS; ATOMISING APPARATUS; NOZZLES
# 00100076  ELECTRICALLY-CONDUCTIVE CONNECTIONS; STRUCTURA...
# ...                                                     ...
# 99973210                  ELECTRIC DIGITAL DATA PROCESSING
# 99973211                  ELECTRIC DIGITAL DATA PROCESSING
# 99973216  LOUDSPEAKERS, MICROPHONES, GRAMOPHONE PICK-UPS...
# 99973264  CHEMICAL OR PHYSICAL PROCESSES, e.g. CATALYSIS...
# 99973266  CASTING OF METALS; CASTING OF OTHER SUBSTANCES...
# 99973272  TYPEWRITERS; SELECTIVE PRINTING MECHANISMS, i....
# 99973298  MACROMOLECULAR COMPOUNDS OBTAINED OTHERWISE TH...
# 99973305  CHEMICAL OR PHYSICAL PROCESSES, e.g. CATALYSIS...
# 99973310                                            ALLOYS
# 99973311  SEMICONDUCTOR DEVICES; ELECTRIC SOLID STATE DE...
# 99973320  DEVICES FOR MOVING WINGS INTO OPEN OR CLOSED P...
# 99973325  SEMICONDUCTOR DEVICES; ELECTRIC SOLID STATE DE...
# 99973331           OPTICAL ELEMENTS, SYSTEMS, OR APPARATUS
# 99973341  INFORMATION STORAGE BASED ON RELATIVE MOVEMENT...
# 99973349  SEMICONDUCTOR DEVICES; ELECTRIC SOLID STATE DE...
# 99973352  SEMICONDUCTOR DEVICES; ELECTRIC SOLID STATE DE...
# 99973360               ELECTROMECHANICAL CLOCKS OR WATCHES
# 99973367  TRANSMISSION OF DIGITAL INFORMATION, e.g. TELE...
# 99973368                                      TRANSMISSION
# 99973369           PICTORIAL COMMUNICATION, e.g. TELEVISION
# 99973370                    WIRELESS COMMUNICATION NETWORKS
# 99973406  LIME; MAGNESIA; SLAG; CEMENTS; COMPOSITIONS TH...
# 99973429           OPTICAL ELEMENTS, SYSTEMS, OR APPARATUS
# 99973438  ARRANGEMENTS OR CIRCUITS FOR CONTROL OF INDICA...
# 99973470  METHODS OR APPARATUS FOR STERILISING MATERIALS...
# 99973572  FILTERS IMPLANTABLE INTO BLOOD VESSELS; PROSTH...
# 99973573  WORKING OR PROCESSING OF SHEET METAL OR METAL ...
# 99973580         SINGLE-CRYSTAL GROWTH ; APPARATUS THEREFOR
# 99973592  SEMICONDUCTOR DEVICES; ELECTRIC SOLID STATE DE...
# 99973593  PROCESSES OR MEANS, e.g. BATTERIES, FOR THE DI...
#
#                                                      label2  \
# doc_num
# 00100004  MACHINES, DEVICES, OR PROCESSES FOR GRINDING O...
# 00100005           PICTORIAL COMMUNICATION, e.g. TELEVISION
# 00100008  CIRCUIT ARRANGEMENTS OR SYSTEMS FOR SUPPLYING ...
# 00100009                                               None
# 00100010                                               None
# 00100018                                     STATIC STORES
# 00100023  WALL, FLOOR, OR LIKE COVERING MATERIALS, e.g. ...
# 00100027  WAVEGUIDES; RESONATORS, LINES OR OTHER DEVICES...
# 00100028                                               None
# 00100029  INFORMATION STORAGE BASED ON RELATIVE MOVEMENT...
# 00100030                                               None
# 00100031                                               None
# 00100039                                        SEPARATION
# 00100040                                               None
# 00100042           PICTORIAL COMMUNICATION, e.g. TELEVISION
# 00100043                      PRINTING MACHINES OR PRESSES
# 00100049                                               None
# 00100050                                               None
# 00100051  PRINTED CIRCUITS; CASINGS OR CONSTRUCTIONAL DE...
# 00100053                                               None
# 00100054  LOUDSPEAKERS, MICROPHONES, GRAMOPHONE PICK-UPS...
# 00100065                                               None
# 00100066  SOLDERING OR UNSOLDERING; WELDING; CLADDING OR...
# 00100069  CONJOINT CONTROL OF VEHICLE SUB-UNITS OF DIFFE...
# 00100071                                               None
# 00100072                                               None
# 00100073                                               None
# 00100074  TREATMENT OF WATER, WASTE WATER, SEWAGE, OR SL...
# 00100075  WORKING OR PROCESSING OF SHEET METAL OR METAL ...
# 00100076  VEHICLES, VEHICLE FITTINGS, OR VEHICLE PARTS, ...
# ...                                                     ...
# 99973210           PICTORIAL COMMUNICATION, e.g. TELEVISION
# 99973211  TRANSMISSION OF DIGITAL INFORMATION, e.g. TELE...
# 99973216                                               None
# 99973264  CRACKING HYDROCARBON OILS; PRODUCTION OF LIQUI...
# 99973266                                               None
# 99973272                                               None
# 99973298          COMPOSITIONS OF MACROMOLECULAR COMPOUNDS
# 99973305                  ACYCLIC OR CARBOCYCLIC COMPOUNDS
# 99973310  MODIFYING THE PHYSICAL STRUCTURE OF FERROUS ME...
# 99973311         SINGLE-CRYSTAL GROWTH ; APPARATUS THEREFOR
# 99973320  BOLTS OR FASTENING DEVICES FOR WINGS, SPECIALL...
# 99973325  MEASURING FORCE, STRESS, TORQUE, WORK, MECHANI...
# 99973331                                               None
# 99973341                                               None
# 99973349                                               None
# 99973352  PRINTED CIRCUITS; CASINGS OR CONSTRUCTIONAL DE...
# 99973360  CIRCUIT ARRANGEMENTS OR SYSTEMS FOR SUPPLYING ...
# 99973367                                               None
# 99973368  TRANSMISSION OF DIGITAL INFORMATION, e.g. TELE...
# 99973369                                               None
# 99973370                                               None
# 99973406                                               None
# 99973429  ARRANGEMENTS OR CIRCUITS FOR CONTROL OF INDICA...
# 99973438       ELECTRIC DISCHARGE TUBES OR DISCHARGE LAMPS
# 99973470          COMPOSITIONS OF MACROMOLECULAR COMPOUNDS
# 99973572  ADHESIVES; NON-MECHANICAL ASPECTS OF ADHESIVE ...
# 99973573                                               None
# 99973580                                               None
# 99973592                                               None
# 99973593                                               None
#
#                                                      label3  \
# doc_num
# 00100004                                               None
# 00100005                                               None
# 00100008                                               None
# 00100009                                               None
# 00100010                                               None
# 00100018                                               None
# 00100023                                               None
# 00100027  TUNING RESONANT CIRCUITS; SELECTING RESONANT C...
# 00100028                                               None
# 00100029                                     STATIC STORES
# 00100030                                               None
# 00100031                                               None
# 00100039                                               None
# 00100040                                               None
# 00100042                                               None
# 00100043  ELECTROGRAPHY; ELECTROPHOTOGRAPHY; MAGNETOGRAPHY
# 00100049                                               None
# 00100050                                               None
# 00100051                                               None
# 00100053                                               None
# 00100054                                               None
# 00100065                                               None
# 00100066                                               None
# 00100069                   CONTROLLING COMBUSTION ENGINES ;
# 00100071                                               None
# 00100072                                               None
# 00100073                                               None
# 00100074                                               None
# 00100075                                               None
# 00100076                                               None
# ...                                                     ...
# 99973210                                               None
# 99973211           PICTORIAL COMMUNICATION, e.g. TELEVISION
# 99973216                                               None
# 99973264                                               None
# 99973266                                               None
# 99973272                                               None
# 99973298                                               None
# 99973305  CRACKING HYDROCARBON OILS; PRODUCTION OF LIQUI...
# 99973310                                               None
# 99973311                                               None
# 99973320  SPRINGS; SHOCK-ABSORBERS; MEANS FOR DAMPING VI...
# 99973325                                               None
# 99973331                                               None
# 99973341                                               None
# 99973349                                               None
# 99973352                                               None
# 99973360                                               None
# 99973367                                               None
# 99973368                          TELEPHONIC COMMUNICATION
# 99973369                                               None
# 99973370                                               None
# 99973406                                               None
# 99973429  MEASURING LENGTH, THICKNESS OR SIMILAR LINEAR ...
# 99973438  DISPLAYING; ADVERTISING; SIGNS; LABELS OR NAME...
# 99973470  PREPARATIONS FOR MEDICAL, DENTAL, OR TOILET PU...
# 99973572  LAYERED PRODUCTS, i.e. PRODUCTS BUILT-UP OF ST...
# 99973573                                               None
# 99973580                                               None
# 99973592                                               None
# 99973593                                               None
#
#                                                      label4  \
# doc_num
# 00100004                                               None
# 00100005                                               None
# 00100008                                               None
# 00100009                                               None
# 00100010                                               None
# 00100018                                               None
# 00100023                                               None
# 00100027                                               None
# 00100028                                               None
# 00100029                                               None
# 00100030                                               None
# 00100031                                               None
# 00100039                                               None
# 00100040                                               None
# 00100042                                               None
# 00100043  HANDLING THIN OR FILAMENTARY MATERIAL, e.g. SH...
# 00100049                                               None
# 00100050                                               None
# 00100051                                               None
# 00100053                                               None
# 00100054                                               None
# 00100065                                               None
# 00100066                                               None
# 00100069  VEHICLES, VEHICLE FITTINGS, OR VEHICLE PARTS, ...
# 00100071                                               None
# 00100072                                               None
# 00100073                                               None
# 00100074                                               None
# 00100075                                               None
# 00100076                                               None
# ...                                                     ...
# 99973210                                               None
# 99973211                                               None
# 99973216                                               None
# 99973264                                               None
# 99973266                                               None
# 99973272                                               None
# 99973298                                               None
# 99973305                                               None
# 99973310                                               None
# 99973311                                               None
# 99973320                                               None
# 99973325                                               None
# 99973331                                               None
# 99973341                                               None
# 99973349                                               None
# 99973352                                               None
# 99973360                                               None
# 99973367                                               None
# 99973368                                         SELECTING
# 99973369                                               None
# 99973370                                               None
# 99973406                                               None
# 99973429                                               None
# 99973438                                               None
# 99973470  SPECIFIC USE OF COSMETICS OR SIMILAR TOILET PR...
# 99973572  METHODS OR APPARATUS FOR STERILISING MATERIALS...
# 99973573                                               None
# 99973580                                               None
# 99973592                                               None
# 99973593                                               None
#
#                                                      label5 label6 label7  \
# doc_num
# 00100004                                               None   None   None
# 00100005                                               None   None   None
# 00100008                                               None   None   None
# 00100009                                               None   None   None
# 00100010                                               None   None   None
# 00100018                                               None   None   None
# 00100023                                               None   None   None
# 00100027                                               None   None   None
# 00100028                                               None   None   None
# 00100029                                               None   None   None
# 00100030                                               None   None   None
# 00100031                                               None   None   None
# 00100039                                               None   None   None
# 00100040                                               None   None   None
# 00100042                                               None   None   None
# 00100043  TYPEWRITERS; SELECTIVE PRINTING MECHANISMS, i....   None   None
# 00100049                                               None   None   None
# 00100050                                               None   None   None
# 00100051                                               None   None   None
# 00100053                                               None   None   None
# 00100054                                               None   None   None
# 00100065                                               None   None   None
# 00100066                                               None   None   None
# 00100069                                               None   None   None
# 00100071                                               None   None   None
# 00100072                                               None   None   None
# 00100073                                               None   None   None
# 00100074                                               None   None   None
# 00100075                                               None   None   None
# 00100076                                               None   None   None
# ...                                                     ...    ...    ...
# 99973210                                               None   None   None
# 99973211                                               None   None   None
# 99973216                                               None   None   None
# 99973264                                               None   None   None
# 99973266                                               None   None   None
# 99973272                                               None   None   None
# 99973298                                               None   None   None
# 99973305                                               None   None   None
# 99973310                                               None   None   None
# 99973311                                               None   None   None
# 99973320                                               None   None   None
# 99973325                                               None   None   None
# 99973331                                               None   None   None
# 99973341                                               None   None   None
# 99973349                                               None   None   None
# 99973352                                               None   None   None
# 99973360                                               None   None   None
# 99973367                                               None   None   None
# 99973368                                               None   None   None
# 99973369                                               None   None   None
# 99973370                                               None   None   None
# 99973406                                               None   None   None
# 99973429                                               None   None   None
# 99973438                                               None   None   None
# 99973470                                               None   None   None
# 99973572  PREPARATIONS FOR MEDICAL, DENTAL, OR TOILET PU...   None   None
# 99973573                                               None   None   None
# 99973580                                               None   None   None
# 99973592                                               None   None   None
# 99973593                                               None   None   None
#
#          label8 label9 label10 label11 label12 label13 label14
# doc_num
# 00100004   None   None    None    None    None    None    None
# 00100005   None   None    None    None    None    None    None
# 00100008   None   None    None    None    None    None    None
# 00100009   None   None    None    None    None    None    None
# 00100010   None   None    None    None    None    None    None
# 00100018   None   None    None    None    None    None    None
# 00100023   None   None    None    None    None    None    None
# 00100027   None   None    None    None    None    None    None
# 00100028   None   None    None    None    None    None    None
# 00100029   None   None    None    None    None    None    None
# 00100030   None   None    None    None    None    None    None
# 00100031   None   None    None    None    None    None    None
# 00100039   None   None    None    None    None    None    None
# 00100040   None   None    None    None    None    None    None
# 00100042   None   None    None    None    None    None    None
# 00100043   None   None    None    None    None    None    None
# 00100049   None   None    None    None    None    None    None
# 00100050   None   None    None    None    None    None    None
# 00100051   None   None    None    None    None    None    None
# 00100053   None   None    None    None    None    None    None
# 00100054   None   None    None    None    None    None    None
# 00100065   None   None    None    None    None    None    None
# 00100066   None   None    None    None    None    None    None
# 00100069   None   None    None    None    None    None    None
# 00100071   None   None    None    None    None    None    None
# 00100072   None   None    None    None    None    None    None
# 00100073   None   None    None    None    None    None    None
# 00100074   None   None    None    None    None    None    None
# 00100075   None   None    None    None    None    None    None
# 00100076   None   None    None    None    None    None    None
# ...         ...    ...     ...     ...     ...     ...     ...
# 99973210   None   None    None    None    None    None    None
# 99973211   None   None    None    None    None    None    None
# 99973216   None   None    None    None    None    None    None
# 99973264   None   None    None    None    None    None    None
# 99973266   None   None    None    None    None    None    None
# 99973272   None   None    None    None    None    None    None
# 99973298   None   None    None    None    None    None    None
# 99973305   None   None    None    None    None    None    None
# 99973310   None   None    None    None    None    None    None
# 99973311   None   None    None    None    None    None    None
# 99973320   None   None    None    None    None    None    None
# 99973325   None   None    None    None    None    None    None
# 99973331   None   None    None    None    None    None    None
# 99973341   None   None    None    None    None    None    None
# 99973349   None   None    None    None    None    None    None
# 99973352   None   None    None    None    None    None    None
# 99973360   None   None    None    None    None    None    None
# 99973367   None   None    None    None    None    None    None
# 99973368   None   None    None    None    None    None    None
# 99973369   None   None    None    None    None    None    None
# 99973370   None   None    None    None    None    None    None
# 99973406   None   None    None    None    None    None    None
# 99973429   None   None    None    None    None    None    None
# 99973438   None   None    None    None    None    None    None
# 99973470   None   None    None    None    None    None    None
# 99973572   None   None    None    None    None    None    None
# 99973573   None   None    None    None    None    None    None
# 99973580   None   None    None    None    None    None    None
# 99973592   None   None    None    None    None    None    None
# 99973593   None   None    None    None    None    None    None
#
# [25000 rows x 14 columns]

# %%
# data cleaning 
assert Y['label1'].isnull().sum() == 0 # there is no document with 

print("{} documents with null title".format(X['title'].isnull().sum()))
print("{} documents with null claims".format(X['claim'].isnull().sum()))
print("{} documents with null abstract".format(X['abstract'].isnull().sum()))
print("{} documents with null description".format(X['desc'].isnull().sum()))

# remove documents with null sections (title and abstract)
X_clean = X.dropna(how='any')
null_idx = X[~X.index.isin(X_clean.index)].index # storing the removed indices (i.e. document numbers)
assert X.shape[0] - null_idx.shape[0] == X_clean.shape[0] # making sure the row counts match

# removing the documents with null sections from the labels as well 
Y_clean = Y.loc[X_clean.index]

# some checks
assert X_clean.shape[0] == Y_clean.shape[0]
assert ((Y_clean.index == X_clean.index)*1).sum() == X_clean.shape[0]

# lower casing everything
X_clean = X_clean.apply(lambda x: x.str.lower())
Y_clean = Y_clean.apply(lambda x: x.str.lower())
# Out:
# 0 documents with null title
# 0 documents with null claims
# 0 documents with null abstract
# 0 documents with null description

# %%
X_clean.shape
# Out:
# (25000, 4)

# %%
# creating data set 
# in this first pass we will concat the text of all patent sections 
# for labels we will use the first label only 

data = pd.DataFrame()
data['full_text'] = X_clean['title'] + " " + X_clean['claim'] + " " + X_clean['abstract'] + " " + X_clean['desc']
data['label1'] = Y_clean['label1']

#data.full_text[100005]

# %%
#data["len"] =  data.full_text.str.len()
data
# Out:
#                                                   full_text  \
# doc_num
# 00100004  planarization apparatus and method a planariza...
# 00100005  image downsampling using redundant pixel remov...
# 00100008  electric power variation compensating device a...
# 00100009  die for tubular film extrusion a die for the e...
# 00100010  stencil printer a stencil printer comprising: ...
# 00100018  system containing a plurality of drams and a b...
# 00100023  a method of manufacturing coverings and a cove...
# 00100027  high-frequency switch a high-frequency switch ...
# 00100028  a dual mode drum brake device a dual mode drum...
# 00100029  information recording medium an information re...
# 00100030  fiber-optic gyro utilizing pseudorandom-bit-se...
# 00100031  computationally parsimonious forward link rece...
# 00100039  catalyst for purifying exhaust gas a catalyst ...
# 00100040  microscope a microscope comprising a support s...
# 00100042  integral positioning and imaging device an ima...
# 00100043  paper level determination a method of determin...
# 00100049  improved electromagnetic actuator for washing ...
# 00100050  refrigeration appliance with means to indicate...
# 00100051  process for producing non-contact data carrier...
# 00100053  header for milking units with a flow adjuster ...
# 00100054  method and apparatus for the reproduction of m...
# 00100065  method and apparatus for reconstructing a line...
# 00100066  procedure for the separation of microfused pie...
# 00100069  vehicle control apparatus and method sharing c...
# 00100071  electrochemical capacitors an electrochemical ...
# 00100072  electrophotographic photosensitive member, pro...
# 00100073  process for producing electrophotographic phot...
# 00100074  method for treating waste water a method for t...
# 00100075  nozzle for hydrostatic forming and hydrostatic...
# 00100076  device for removing a wire harness from a vehi...
# ...                                                     ...
# 99973210  information providing device and method an inf...
# 99973211  information providing device and method an inf...
# 99973216  speaker device a speaker apparatus comprising:...
# 99973264  catalyst for hydrofining and method for prepar...
# 99973266  molding powder for continuous casting of steel...
# 99973272  ink-jet head, ink-jet printer, and its driving...
# 99973298  process for producing modified phenolic resin ...
# 99973305  method for isomerization of hydrocarbon, and s...
# 99973310  high strength cold rolled steel plate and meth...
# 99973311  silicon wafer and method of manufacture thereo...
# 99973320  rotary damper a rotary damper comprising a cas...
# 99973325  semiconductor pressure sensor and its manufact...
# 99973331  arrayed waveguide grating multiplexer and demu...
# 99973341  optical recording medium, recorder for optical...
# 99973349  method and apparatus for processing wafer a su...
# 99973352  rf circuit module an rf circuit module compris...
# 99973360  electronic device, electronic timepiece and po...
# 99973367  method and apparatus for network control a net...
# 99973368  channel check test system a channel check test...
# 99973369  serial digital interface system transmission/r...
# 99973370  traffic control method for mobile data communi...
# 99973406  light-weight cellular concrete with excellent ...
# 99973429  image processor for observing optical fiber an...
# 99973438  ac plasma display panel an ac type plasma disp...
# 99973470  deodorant composition a deodorant composition ...
# 99973572  medical pressure-sensitive adhesive tape a med...
# 99973573  metal sheet bending device the apparatus for b...
# 99973580  method for producing single crystal and pullin...
# 99973592  light emitting diode and its manufacturing met...
# 99973593  material of positive plate for lithium seconda...
#
#                                                      label1
# doc_num
# 00100004  semiconductor devices; electric solid state de...
# 00100005   image data processing or generation, in general
# 00100008                                        wind motors
# 00100009  shaping or joining of plastics; shaping of sub...
# 00100010  apparatus or devices for manifolding, duplicat...
# 00100018                  electric digital data processing
# 00100023  shaping or joining of plastics; shaping of sub...
# 00100027                                      transmission
# 00100028               couplings for transmitting rotation
# 00100029  materials for applications not otherwise provi...
# 00100030  measuring distances, levels or bearings; surve...
# 00100031                                      transmission
# 00100039  chemical or physical processes, e.g. catalysis...
# 00100040           optical elements, systems, or apparatus
# 00100042   image data processing or generation, in general
# 00100043  counting mechanisms; counting of objects not o...
# 00100049  magnets; inductances; transformers; selection ...
# 00100050  refrigerators; cold rooms; ice-boxes; cooling ...
# 00100051  recognition of data; presentation of data; rec...
# 00100053                     manufacture of dairy products
# 00100054                              stereophonic systems
# 00100065  speech analysis or synthesis; speech recogniti...
# 00100066  dentistry; apparatus or methods for oral or de...
# 00100069  control or regulating systems in general; func...
# 00100071  capacitors; capacitors, rectifiers, detectors,...
# 00100072  electrography; electrophotography; magnetography
# 00100073  electrography; electrophotography; magnetography
# 00100074                                        separation
# 00100075  spraying apparatus; atomising apparatus; nozzles
# 00100076  electrically-conductive connections; structura...
# ...                                                     ...
# 99973210                  electric digital data processing
# 99973211                  electric digital data processing
# 99973216  loudspeakers, microphones, gramophone pick-ups...
# 99973264  chemical or physical processes, e.g. catalysis...
# 99973266  casting of metals; casting of other substances...
# 99973272  typewriters; selective printing mechanisms, i....
# 99973298  macromolecular compounds obtained otherwise th...
# 99973305  chemical or physical processes, e.g. catalysis...
# 99973310                                            alloys
# 99973311  semiconductor devices; electric solid state de...
# 99973320  devices for moving wings into open or closed p...
# 99973325  semiconductor devices; electric solid state de...
# 99973331           optical elements, systems, or apparatus
# 99973341  information storage based on relative movement...
# 99973349  semiconductor devices; electric solid state de...
# 99973352  semiconductor devices; electric solid state de...
# 99973360               electromechanical clocks or watches
# 99973367  transmission of digital information, e.g. tele...
# 99973368                                      transmission
# 99973369           pictorial communication, e.g. television
# 99973370                    wireless communication networks
# 99973406  lime; magnesia; slag; cements; compositions th...
# 99973429           optical elements, systems, or apparatus
# 99973438  arrangements or circuits for control of indica...
# 99973470  methods or apparatus for sterilising materials...
# 99973572  filters implantable into blood vessels; prosth...
# 99973573  working or processing of sheet metal or metal ...
# 99973580         single-crystal growth ; apparatus therefor
# 99973592  semiconductor devices; electric solid state de...
# 99973593  processes or means, e.g. batteries, for the di...
#
# [25000 rows x 2 columns]

# %%
# examing the document length 
doc_lenghts = data.full_text.str.len()
print("Average document length: {} words".format(round(np.mean(doc_lenghts))))
print("Median document length: {} words".format(round(np.median(doc_lenghts))))
print("Max document length: {} words".format(round(np.max(doc_lenghts))))
print("Min document length: {} words".format(round(np.min(doc_lenghts))))
# Out:
# Average document length: 2556 words
# Median document length: 2583.0 words
# Max document length: 5961 words
# Min document length: 1056 words

# %% [markdown]
# ### Train Test Split

# %%
# train test split 
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(data['full_text'], data['label1'], test_size=0.2)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (18486,)
# (4622,)
# (18486,)
# (4622,)

# %% [markdown]
# ### Encoding Labels

# %%
# encode the target variable 
encoder = preprocessing.LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
Y_test = encoder.fit_transform(Y_test)

#pd.Series(Y_train).value_counts(sort=True)

Y_train
# Out:
# array([242,  86,  20, ..., 369,  83, 351])

# %% [markdown]
# ### Word Embeddings

# %% [markdown]
# **Load the pre-trained embeddings using this command:**
#
# `nohup curl -O https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki-news-300d-1M.vec.zip > curl.nohup.out 2>&1 &`
#
# Check loading progress with this: `cat curl.nohup.out`

# %%
# sequence length is set to median document length
sequence_length = 2580
embedding_dim = 300

# %%
# word-embeddings: representing documents using a dense vector representation
# Word embeddings can be trained using the input corpus itself or 
# can be generated using pre-trained word embeddings such as Glove, FastText, and Word2Vec

# step 1. Loading the pretrained word embeddings
embeddings_index = {}
for i, line in enumerate(open('pretrained_word_embeddings/wiki-news-300d-1M.vec')):
    values = line.split()
    embeddings_index[values[0]] = np.asarray(values[1:], dtype='float32')

# %%
# step 2. Creating a tokenizer object using Keras preprocessing object 
# the tokenizer has a default filter that removes all punctuation, plus tabs and line breaks, minus the ' character.
token = text.Tokenizer()
token.fit_on_texts(data['full_text'])
word_index = token.word_index

# %%
print('Number of words in our vocabulary: {}'.format(len(word_index.keys())))
# Out:
# Number of words in our vocabulary: 71451

# %%
# step 3. Transforming text documents to sequence of tokens and padding them to ensure equal length vectors
# choosing the median document length as max length for padding 
X_train_seq = sequence.pad_sequences(token.texts_to_sequences(X_train), maxlen=sequence_length)
X_test_seq = sequence.pad_sequences(token.texts_to_sequences(X_test), maxlen=sequence_length)

# %%
X_train_seq.shape
# Out:
# (18486, 2580)

# %%
# step 4. Creating a mapping of tokens and their respective embeddings
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_matrix.shape
# Out:
# (71452, 300)

# %%
X_train_seq.shape
# Out:
# (18486, 2580)

# %% [markdown]
# ### CNN

# %%
# Define Parameters 
batch_size = 32
epochs = 2

vocabulary_size = len(word_index) + 1
sequence_length = sequence_length
embedding_dim = embedding_dim
num_filters = 100
kernel_size = 3 # 3 by emb dim 
units = pd.Series(Y_train).value_counts().shape[0]

# %%
# Input Layer
input_layer = Input(shape=(sequence_length,), dtype='int32')

# Word embedding Layer
embedding_layer = Embedding(input_dim=vocabulary_size, output_dim=embedding_dim, input_length=sequence_length, 
                            weights=[embedding_matrix], trainable=False)(input_layer)
embedding_layer = SpatialDropout1D(0.3)(embedding_layer)

# Convolutional Layer
conv_layer = Conv1D(num_filters, kernel_size=kernel_size, activation="relu")(embedding_layer)

# Pooling Layer
pooling_layer = GlobalMaxPool1D()(conv_layer)

# Output Layers
output_layer1 = Dense(50, activation="relu")(pooling_layer)
output_layer1 = Dropout(0.25)(output_layer1)
output_layer2 = Dense(units= units, activation="softmax")(output_layer1)

# Compile the model
model = models.Model(inputs=input_layer, outputs=output_layer2,)
model.compile(optimizer=optimizers.Adam(lr=1e-3), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 2580)              0
# _________________________________________________________________
# embedding_10 (Embedding)     (None, 2580, 300)         21435600
# _________________________________________________________________
# spatial_dropout1d_9 (Spatial (None, 2580, 300)         0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 2578, 100)         90100
# _________________________________________________________________
# global_max_pooling1d_6 (Glob (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 532)               27132
# =================================================================
# Total params: 21,557,882
# Trainable params: 122,282
# Non-trainable params: 21,435,600
# _________________________________________________________________

# %%
pd.Series(Y_train).value_counts().shape[0]
# Out:
# 532

# %%
from keras.utils import to_categorical
y_binary = to_categorical(Y_train)
y_binary.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-9fbdf413092a> in <module>()
#       1 from keras.utils import to_categorical
# ----> 2 y_binary = to_categorical(Y_train)
#       3 y_binary.shape
#
# NameError: name 'Y_train' is not defined

# %%
# Training 
history = model.fit(X_train_seq, y_binary,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 16637 samples, validate on 1849 samples
# Epoch 1/2
# 16637/16637 [==============================] - 556s 33ms/step - loss: 5.3057 - acc: 0.0538 - val_loss: 5.1717 - val_acc: 0.0562
# Epoch 2/2
# 16637/16637 [==============================] - 717s 43ms/step - loss: 5.1757 - acc: 0.0546 - val_loss: 5.1681 - val_acc: 0.0562

# %% [markdown]
# ## Model

# %%
# define parameters
batch_size = 32
epochs = 2

# %%
# simple fully connected layer NN

model = Sequential()
model.add(Dense(512, input_shape=(max_words,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)

score = model.evaluate(x_test, y_test,
                       batch_size=batch_size, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])

# %%
# fit
